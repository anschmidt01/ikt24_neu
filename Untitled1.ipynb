3 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/6.9 MB 10.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.9 MB 10.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 10.3 MB/s eta 0:00:01
#    ------------------------- -------------- 4.4/6.9 MB 10.3 MB/s eta 0:00:01
#    --------------------------- ------------ 4.8/6.9 MB 10.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/6.9 MB 10.3 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 9.8 MB/s eta 0:00:00
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
#    ---------------------------------------- 0.0/241.6 kB ? eta -:--:--
#    --------------------------------------- 241.6/241.6 kB 15.4 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading watchdog-4.0.2-py3-none-win_amd64.whl (82 kB)
#    ---------------------------------------- 0.0/82.9 kB ? eta -:--:--
#    ---------------------------------------- 82.9/82.9 kB 4.5 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 5.2 MB/s eta 0:00:00
# Downloading narwhals-1.8.2-py3-none-any.whl (167 kB)
#    ---------------------------------------- 0.0/167.7 kB ? eta -:--:--
#    ---------------------------------------- 167.7/167.7 kB 5.1 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, typing-extensions, toml, tenacity, smmap, pyarrow, protobuf, narwhals, mdurl, click, cachetools, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
# Successfully installed altair-5.4.1 blinker-1.8.2 cachetools-5.5.0 click-8.1.7 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.8.2 protobuf-5.28.2 pyarrow-17.0.0 pydeck-0.9.1 rich-13.8.1 smmap-5.0.1 streamlit-1.38.0 tenacity-8.5.0 toml-0.10.2 typing-extensions-4.12.2 watchdog-4.0.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script watchmedo.exe is installed in 'C:\Users\Toni\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'C:\Users\Toni\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit.exe is installed in 'C:\Users\Toni\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Toni\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# Title of the Streamlit app
st.title("Attendance Forecasting for Modules - Starting October 2024")

# Load the forecasted data
@st.cache  # Cache data to avoid reloading on each interaction
def load_data():
    return pd.read_csv("attendance_forecast_per_module.csv")  # Ensure this file path is correct

# Load the data
df_forecast = load_data()

# Sidebar: Select a module to view its forecast
module = st.sidebar.selectbox("Select Module", df_forecast['module'].unique())

# Filter the data for the selected module
df_selected_module = df_forecast[df_forecast['module'] == module]

# Display the dataframe in the Streamlit app
st.subheader(f"Forecasted Attendance for {module}")
st.write(df_selected_module)

# Plotting the forecasted data
st.subheader(f"Attendance Forecast Plot for {module}")

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(df_selected_module['ds'], df_selected_module['yhat'], label=f'Forecasted Attendance for {module}', color='blue')
plt.xlabel('Date')
plt.ylabel('Attendance')
plt.title(f'Forecasted Attendance for {module} from October 2024')
plt.legend()
plt.tight_layout()

# Display the plot in Streamlit
st.pyplot(plt)

# Optionally, let users download the forecast data
st.subheader("Download Forecast Data")
st.download_button(
    label="Download Forecast CSV",
    data=df_forecast.to_csv().encode('utf-8'),
    file_name='attendance_forecast_all_modules_october_2024.csv',
    mime='text/csv'
)
# Out:
# 2024-09-22 00:19:17.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.892
# `st.cache` is deprecated and will be removed soon. Please use one of Streamlit's new
# caching commands, `st.cache_data` or `st.cache_resource`. More information
# [in our docs](https://docs.streamlit.io/develop/concepts/architecture/caching).
#
# **Note**: The behavior of `st.cache` was updated in Streamlit 1.36 to the new caching
# logic used by `st.cache_data` and `st.cache_resource`. This might lead to some problems
# or unexpected behavior in certain edge cases.
#
# 2024-09-22 00:19:17.896 No runtime found, using MemoryCacheStorageManager
# 2024-09-22 00:19:17.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.904 No runtime found, using MemoryCacheStorageManager
# 2024-09-22 00:19:17.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.940 Session state does not function when running a script without `streamlit run`
# 2024-09-22 00:19:17.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:17.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:18.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-22 00:19:19.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# False

# %%
streamlit run app.py
# Out:
#   Cell In[4], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
